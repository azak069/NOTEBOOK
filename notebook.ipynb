# %% [markdown]
# # Pengenalan Notebook

# %% [markdown]
# - ctrl/cmd+enter: run
# - shift+enter: run + jump to next cell (create new one if none exists)
# - alt+enter: run + insert a new code cell below it

# %%
# melakukan coding python di Jupyter Notebook
a = "Hello, World!"
print(a)
# Out:
# Hello, World!

# %%
a = 10
print(a)
# Out:
# 10

# %%
b = 15
b # tidak perlu print jika hanya satu variabel di akhir cell
# Out:
# 15

# %% [markdown]
# # Shell Commands
# Untuk mengecek commands lain yang tersedia di Linux, kamu dapat mengeceknya di [sini](https://courses.cs.washington.edu/courses/cse390a/14au/bash.html).

# %%
# menggunakan perintah shell di Jupyter Notebook
# !ls # menampilkan daftar file di direktori saat ini
# Out:
# sample_data

# %%
# !pwd # menampilkan direktori kerja saat ini
# Out:
# /content

# %% [markdown]
# # Magics

# %%
import numpy as np

# %timeit np.linalg.eigvals(np.random.rand(100, 100))
# mengukur waktu eksekusi dari sebuah perintah dengan magic command %timeit
# Out:
# The slowest run took 4.24 times longer than the fastest. This could mean that an intermediate result is being cached.
# 100 loops, best of 5: 8.07 ms per loop

# %%
# %%HTML # menggunakan HTML di Jupyter Notebook
# <marquee style='width:30%; color: green;'>Hello World!</marquee>
# Out:
# <marquee style='width:30%; color: green;'>Hello World!</marquee>

# %% [markdown]
# # Documentation

# %%
np.random?
# menampilkan dokumentasi dari fungsi np.random
# Out:
# Object `np.random` not found.

# %% [markdown]
# # Markdown

# %% [markdown]
# **Python** *Programming*

# %% [markdown]
# [Google Website](https://google.com)

# %% [markdown]
# 1. Apples
# 1. Oranges
# 1. Mangoes
# 1. Grapes

# %% [markdown]
# * Apples
# * Oranges
# * Mangoes

# %% [markdown]
# * Apples
#   1. Apple 1
#   1. Apple 2
#   1. Apple 3

# %% [markdown]
# LaTex Syntax:
# Use MathJax Rendering

# %% [markdown]
# $\sqrt{9}+1^3$

# %% [markdown]
# Nama Makanan | Harga
# --- | ---
# Nasi Goreng | 25000
# Es Teh Manis | 3500
